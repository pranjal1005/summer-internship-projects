# %% [markdown]
# <a href="https://colab.research.google.com/github/pranjal1005/summer-internship-projects/blob/main/trainingday13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a = pd.Series([1,233,67,90])

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a = {
    "Name" : ['Sam', 'Raj', 'Rahul', 'Gaurav'],
    "Domain" : ['D.E' , 'D.S', 'D.E', 'FULL STACK'],
    "Duration" : [30,15,45,30]

}

# %%
df = pd.DataFrame(a)
df
# Out:
#      Name      Domain  Duration
# 0     Sam         D.E        30
# 1     Raj         D.S        15
# 2   Rahul         D.E        45
# 3  Gaurav  FULL STACK        30

# %%
df.to_csv('intern_student.csv')

# %%
import pandas as pd

pd.read_csv("jaipur_restro.csv")
# Out:
#                                                OSrXXb      rllt__details  \
# 0                                        The Magnolia    ·  · Restaurant
# 1                                  Skyfall Restaurant    ·  · Restaurant
# 2                 J Brew & Kitchen Rooftop Restaurant  ·  · North Indian
# 3                                                 NaN                NaN
# 4                                       Suvarna Mahal  ·  · North Indian
# 5                                    Govindam Retreat    ·  · Restaurant
# 6                                           Anushthan  ·  · North Indian
# 7                                  Peacock Restaurant  ·  · North Indian
# 8                                         Queen's hub    ·  · Restaurant
# 9                             Handi restaurant jaipur    ·  · Restaurant
# 10  Annpoornam - Best South Indian Restaurant In J...  ·  · South Indian
# 11                                 Monarch Restaurant           · Indian
# ...

# %%
import pandas as pd

pd.read_csv("flipkart.csv")
# Out:
#                                           CGtC98 href  \
# 0   https://www.flipkart.com/cmf-nothing-phone-2-p...
# 1   https://www.flipkart.com/realme-p3-ultra-5g-gl...
# 2   https://www.flipkart.com/samsung-galaxy-a36-5g...
# 3   https://www.flipkart.com/realme-14-pro-5g-sued...
# 4   https://www.flipkart.com/oneplus-13r-5g-nebula...
# 5   https://www.flipkart.com/vivo-v50-5g-rose-red-...
# 6   https://www.flipkart.com/realme-gt-6-fluid-sil...
# 7   https://www.flipkart.com/realme-14-pro-5g-pear...
# 8   https://www.flipkart.com/realme-14-pro-5g-sued...
# 9   https://www.flipkart.com/realme-13-pro-5g-emer...
# 10  https://www.flipkart.com/realme-gt-6-razor-gre...
# 11  https://www.flipkart.com/vivo-t3-ultra-frost-g...
# 12  https://www.flipkart.com/oneplus-13r-5g-nebula...
# 13  https://www.flipkart.com/samsung-galaxy-a36-5g...
# 14  https://www.flipkart.com/realme-14-pro-5g-bika...
# 15  https://www.flipkart.com/realme-gt-6-fluid-sil...
# ...

# %%
pd.read_csv("makemytrip.csv")
# Out:
#                                              makeFlex  \
# 0                                             FlixBus
# 1                           Shree Raj Akanshi travels
# 2                                Vikas Travels Jaipur
# 3                             PAL BUS(Patel Travels®)
# 4   Shri Krishna Travels ( Jai Shree Ganesh Yatra ...
# 5                                        Zingbus Plus
# 6                          Ram Dalal Holidays Pvt Ltd
# 7                                    Maharani Travels
# 8                                   Mahalaxmi Travels
# 9                                             FlixBus
# 10                                       Zingbus Plus
# 11                                     NAVEEN TRAVELS
# 12                                  Mahalaxmi Travels
# 13                                     NAVEEN TRAVELS
# 14                                  Mahalaxmi Travels
# 15  Shri Krishna Travels ( Jai Shree Ganesh Yatra ...
# ...

# %%
pd.read_csv("naukri.csv")
# Out:
#                                                 title  \
# 0         Data Scientist-Knowledge management science
# 1   Data Scientist - Machine Learning/Artificial I...
# 2                                      Data Scientist
# 3                           Data Scientist - Python/R
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                                      Data Scientist
# 8                                      Data Scientist
# 9                                      Data Scientist
# 10                         Data Scientist-Credit Risk
# 11             Data Scientist-Artificial Intelligence
# 12                                     Data Scientist
# 13                       ML Engineer / Data Scientist
# 14  Walk-In Fresher's /Exp For Global MNCs -Data-S...
# 15                                       Data Analyst
# ...
